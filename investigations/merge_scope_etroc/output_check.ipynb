# %%
import sys
sys.path.append('/home/etl/Test_Stand/tbanalyisis/') #stupid python
import os
import numpy as np
from utils import plotting as pu
from utils import analysis as au
import awkward as ak
import importlib
import uproot

import matplotlib.pyplot as plt
import hist
import mplhep as hep

# %%
#new dts

importlib.reload(pu)
ts_data = "/home/etl/Test_Stand/tbanalyisis/output_analysis_data/merge_etroc_first_test_actually_for_real_this_time/start_6685_stop_6809_setup_40-36_offset_15.0_energy_120.0_power_i1_module_40_bias_230_file_from_SPS_LP2_20_cubicLM_unbinned"
ts = pu.TBplot(
    ts_data
)
ts.cut_eff_plot()
ts.sensor_map('hits')

ts.heatmap('toa_code', 'tot_code')
ts.histo1D('dt')

ts.histo1D('dt', pix=(7,6))
ts.histo1D('dt_corr', pix=(7,6))

ts.sensor_map('cal_mode')
