# %%
import sys
sys.path.append('/home/users/hswanson13/tbanalysis/') #stupid python
import os
import numpy as np
from utils import plotting as pu
from utils import analysis as au
import awkward as ak
import importlib
import uproot

import matplotlib.pyplot as plt
import hist
import mplhep as hep

# %%
importlib.reload(pu)
uaf_data = "/home/users/hswanson13/tbanalysis/output_analysis_data/merge_scope_etroc_check_unittest/start_6685_stop_6809_setup_40-36_offset_15.0_energy_120.0_power_i1_module_40_bias_230_file_from_SPS_LP2_20_cubicLM_unbinned"

uaf = pu.TBplot(
    uaf_data
)
# uaf.hist_bins['res_shape_comp'] = (75, 0, 250)
uaf.sensor_map('hits')
# uaf.res_shape_comp()

uaf.heatmap('toa_code', 'tot_code')

uaf.histo1D('dt', pix=(7,6))
uaf.histo1D('dt_corr', pix=(7,6))
