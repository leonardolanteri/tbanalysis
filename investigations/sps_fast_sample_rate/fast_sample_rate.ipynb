# %%
import sys
sys.path.append('/home/etl/Test_Stand/tbanalyisis/') #stupid python
import os
import numpy as np
from utils import plotting as pu
from utils import analysis as au
import awkward as ak
import importlib

# %%
# tbplt40 = pu.TBplot(
#     #"/home/etl/Test_Stand/tbanalyisis/output_analysis_data/sps_high_sample_rate_dt/start_7524_stop_7714_setup_36-40_offset_15.0_energy_120.0_power_i1_module_40_bias_240_file_from_SPS_FAST_LP2_20_cubicLM_unbinned",
#     #"/home/etl/Test_Stand/tbanalyisis/output_analysis_data/sps_high_sample_rate_dt/start_7725_stop_7738_setup_36-40_offset_15.0_energy_120.0_power_i1_module_40_bias_245_file_from_SPS_FAST_LP2_20_cubicLM_unbinned",
#     "/home/etl/Test_Stand/tbanalyisis/output_analysis_data/sps_high_sample_rate_dt/start_7925_stop_8124_setup_36-40_offset_20.0_energy_120.0_power_i1_module_40_bias_240_file_from_SPS_FAST_LP2_20_cubicLM_unbinned",
#     load_full_collection=True
# )

# tbplt36 = pu.TBplot(
#     "/home/etl/Test_Stand/tbanalyisis/output_analysis_data/sps_high_sample_rate_dt/start_7524_stop_7714_setup_36-40_offset_15.0_energy_120.0_power_i1_module_36_bias_240_file_from_SPS_FAST_LP2_20_cubicLM_unbinned",
#     #"/home/etl/Test_Stand/tbanalyisis/output_analysis_data/sps_high_sample_rate_dt/start_7725_stop_7738_setup_36-40_offset_15.0_energy_120.0_power_i1_module_36_bias_245_file_from_SPS_FAST_LP2_20_cubicLM_unbinned",
#     #"/home/etl/Test_Stand/tbanalyisis/output_analysis_data/sps_high_sample_rate_dt/start_7925_stop_8124_setup_36-40_offset_20.0_energy_120.0_power_i1_module_36_bias_240_file_from_SPS_FAST_LP2_20_cubicLM_unbinned",
#     #load_full_collection=True
# )

tbplt36_no_scope = pu.TBplot(
    "/home/etl/Test_Stand/tbanalyisis/output_analysis_data/sps_high_sample_rate_dt_no_scope/start_7524_stop_7714_setup_36-40_offset_15.0_energy_120.0_power_i1_module_36_bias_240_file_from_SPS_FAST_LP2_20_cubicLM_unbinned",
    # "/home/etl/Test_Stand/tbanalyisis/output_analysis_data/sps_high_sample_rate_dt_no_scope/start_7725_stop_7738_setup_36-40_offset_15.0_energy_120.0_power_i1_module_36_bias_245_file_from_SPS_FAST_LP2_20_cubicLM_unbinned",
    # "/home/etl/Test_Stand/tbanalyisis/output_analysis_data/sps_high_sample_rate_dt_no_scope/start_7925_stop_8124_setup_36-40_offset_20.0_energy_120.0_power_i1_module_36_bias_240_file_from_SPS_FAST_LP2_20_cubicLM_unbinned",
    load_full_collection=False
)


tbplt = tbplt36_no_scope
#tbplt.hist_bins['dt'] = (100, 14, 15)
tbplt.sensor_map('hits', cmax=2300)
tbplt.sensor_map('cal_mode')

tbplt.heatmap('tot_code', 'toa_code')
tbplt.histo1D('dt', pix=(5,5))
